# %%
from matplotlib import pyplot as plt
import os
os.getcwd()
# Out:
# 'C:\\Users\\Rizqan\\Documents\\NUS\\SP2273\\learning-portfolio-Rizqancaffoor\\Question 5'

# %%
os.chdir('golgi-movie_robert_frames_gray')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rizqan\\Documents\\NUS\\SP2273\\learning-portfolio-Rizqancaffoor\\Question 5\\golgi-movie_robert_frames_gray'

# %%
img_data = plt.imread('golgi-movie_robert_frame_01_gray.jpg')
plt.imshow(img_data, cmap='jet')
plt.colorbar()

# %%
type(img_data) #its an array
# Out:
# numpy.ndarray

# %%
img_data.shape #its a 512 pixel by 512 pixel square
# Out:
# (512, 512)

# %%
img_data #each no. represents a brightness, where 0 represents no brightness (black)
# Out:
# array([[1, 3, 3, ..., 0, 0, 1],
#        [1, 2, 1, ..., 1, 2, 3],
#        [3, 3, 2, ..., 2, 2, 3],
#        ...,
#        [2, 1, 0, ..., 0, 0, 3],
#        [3, 3, 2, ..., 0, 0, 1],
#        [1, 2, 2, ..., 1, 2, 0]], dtype=uint8)

# %%
img_data.min()
# Out:
# 0

# %%
img_data.max() #somewhere in the middle of the array there is a value of 195
# Out:
# 195

# %%
img_data.sum()
# Out:
# 1678097

# %%
plt.style.use('bmh')

plt.hist([img_data.flatten()], #flatten() convert a list or array of nested lists or arrays into a one-dimensional list or array.
        bins=195,
        label=['img_data']
        )
plt.xlabel('brightness')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %%
unique_e, counts = np.unique(img_data, return_counts=True) #use np.unique to obtain each specific element in the array
img_data_dict = dict(zip(unique_e, counts)) #dict(zip()) creates a dictionary from two sequences, one contains the keys and the other contains the corresponding values.
print(img_data_dict)
# Out:
# {0: 17740, 1: 30304, 2: 47595, 3: 48009, 4: 34454, 5: 21305, 6: 12901, 7: 8442, 8: 5653, 9: 4256, 10: 3390, 11: 2642, 12: 2122, 13: 1771, 14: 1575, 15: 1373, 16: 1150, 17: 1001, 18: 879, 19: 829, 20: 701, 21: 605, 22: 575, 23: 539, 24: 483, 25: 450, 26: 407, 27: 392, 28: 335, 29: 309, 30: 278, 31: 292, 32: 261, 33: 295, 34: 239, 35: 228, 36: 230, 37: 215, 38: 197, 39: 170, 40: 213, 41: 168, 42: 171, 43: 158, 44: 173, 45: 185, 46: 176, 47: 147, 48: 147, 49: 169, 50: 150, 51: 150, 52: 139, 53: 146, 54: 163, 55: 140, 56: 128, 57: 137, 58: 124, 59: 129, 60: 124, 61: 136, 62: 135, 63: 121, 64: 120, 65: 141, 66: 129, 67: 114, 68: 109, 69: 91, 70: 123, 71: 108, 72: 89, 73: 110, 74: 85, 75: 97, 76: 105, 77: 109, 78: 88, 79: 95, 80: 64, 81: 70, 82: 76, 83: 85, 84: 89, 85: 63, 86: 67, 87: 60, 88: 76, 89: 70, 90: 66, 91: 60, 92: 65, 93: 67, 94: 61, 95: 61, 96: 50, 97: 48, 98: 54, 99: 60, 100: 44, 101: 38, 102: 38, 103: 35, 104: 38, 105: 39, 106: 27, 107: 36, 108: 31, 109: 37, 110: 31, 111: 31, 112: 32, 113: 18, 114: 21, 115: 21, 116: 21, 117: 27, 118: 31, 119: 13, 120: 14, 121: 18, 122: 19, 123: 8, 124: 19, 125: 11, 126: 10, 127: 12, 128: 10, 129: 6, 130: 11, 131: 6, 132: 13, 133: 8, 134: 6, 135: 9, 136: 4, 137: 5, 138: 8, 139: 3, 140: 5, 141: 10, 142: 7, 143: 5, 144: 6, 145: 7, 146: 2, 147: 1, 148: 2, 149: 4, 150: 1, 151: 2, 152: 1, 153: 2, 154: 6, 155: 4, 156: 3, 158: 2, 160: 3, 161: 2, 163: 1, 164: 2, 165: 1, 166: 1, 168: 1, 171: 2, 172: 1, 178: 2, 182: 1, 190: 1, 195: 1}

# %%
total = []
for i in range(1, 18):
    img_data = plt.imread(f"golgi-movie_robert_frame_{i:>02}_gray.jpg")
    total.append(img_data.sum())
print(total)
# Out:
# [1678097, 1635644, 1816652, 1777037, 1747933, 1689746, 1651677, 1603658, 1484451, 1413813, 1339107, 1287205, 1223687, 1170396, 1123362, 1057297, 1030133]

# %%
import numpy as np
total_array = np.array(total)
max_value = total_array.max()
percentage_array = total_array/max_value
# Out:
# [0.92373058 0.90036176 1.         0.9781934  0.96217272 0.93014292
#  0.90918734 0.88275465 0.81713559 0.77825197 0.73712907 0.70855893
#  0.67359461 0.64425988 0.6183694  0.58200305 0.56705027]

# %%
plt.figure(figsize=(17, 5))
plt.plot([i for i in range(1, 18)], percentage_array, marker='o', linestyle='dashed')
plt.xlabel('Frame Number')
plt.ylabel('Total fluorescence')
plt.xticks(range(1, 18))

plt.show()
